# %%
print("PROGRAMA PARA OBTENER RAICES CON LA FORMULA GENERAL")
print("ECUACION TIPO: ax^2+bx+c")

import math

disc = -1
while disc < 0:
  a=int (input("Ingresa el valor de ax^2: "))
  b=int (input("Ingresa el valor de bx: "))
  c=int (input("ingresa el valor de c: "))

  disc = (b**2)-(4 * a * c)

  if disc < 0:
    print("Error, el discriminante debe de ser positivo")

    resl=(-1) * b

res2= math.sqrt(disc)
res3= (resl + res2)/(2 * a)
res4= (resl - res2)/(2 * a)

print ("los valores de x son:")
print ("X1 = ", res3)
print ("X2 = ", res4)
# Out:
# PROGRAMA PARA OBTENER RAICES CON LA FORMULA GENERAL
# ECUACION TIPO: ax^2+bx+c
# Ingresa el valor de ax^2: 2
# Ingresa el valor de bx: 8
# ingresa el valor de c: 8
# los valores de x son:
# X1 =  -1.5
# X2 =  -1.5

# %%
print("PROGRAMA PARA EVALUAR LA FUNCION F(x)= x^2 + 3x + 3 ")

def FUNCION (x, des):
  res= (x**2)+(3*x)
  des= res + 3
  return des

a= -5
b= 10
C= 1

while a <= b and FUNCION (a,c) >=0.0025:
  a=a + 1
  A=[FUNCION (a,c)]
  print("el valor de la funcion es ", a, "=")
  print(A)
# Out:
# PROGRAMA PARA EVALUAR LA FUNCION F(x)= x^2 + 3x + 3
# el valor de la funcion es  -4 =
# [7]
# el valor de la funcion es  -3 =
# [3]
# el valor de la funcion es  -2 =
# [1]
# el valor de la funcion es  -1 =
# [1]
# el valor de la funcion es  0 =
# [3]
# el valor de la funcion es  1 =
# [7]
# el valor de la funcion es  2 =
# [13]
# el valor de la funcion es  3 =
# [21]
# el valor de la funcion es  4 =
# [31]
# el valor de la funcion es  5 =
# [43]
# el valor de la funcion es  6 =
# [57]
# el valor de la funcion es  7 =
# [73]
# el valor de la funcion es  8 =
# [91]
# el valor de la funcion es  9 =
# [111]
# el valor de la funcion es  10 =
# [133]
# el valor de la funcion es  11 =
# [157]
